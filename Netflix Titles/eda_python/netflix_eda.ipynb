# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\Data Project\Netflix Movies and TV Shows\netflix-eda-python\netflix_titles.csv")

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.nunique() #Unique values in each column
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# check duplicated sum
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# since director take a good part of the data lets fill the NA of objects with Unknown instead of cleaning them(only date added Nan including rows will be removed)
df=df[df['date_added'].notna()] #returns a boolean mask (True/False for each row).df[...] filters rows where the condition is True. Means Keep only rows where date_added is not null
#df['director'].fillna('Not Available', inplace=True)
#df['cast'].fillna('Not Available', inplace=True)
#df['country'].fillna('Unknown', inplace=True)
#df['rating'].fillna('Unknown', inplace=True)
#df['duration'].fillna('Unknown', inplace=True)
#i am using loop on this
fill_values={
    'director': 'Not Available',
    'cast': 'Not Available',
    'country': 'Unknown',
    'rating': 'Unknown',
    'duration': 'Unknown'
}
for k,v in fill_values.items():
    df[k].fillna(v,inplace=True)
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_5004\4142081291.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[k].fillna(v,inplace=True)
# C:\Users\shabi\AppData\Local\Temp\ipykernel_5004\4142081291.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[k].fillna(v,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8797 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8797 non-null   object
#  1   type          8797 non-null   object
#  2   title         8797 non-null   object
#  3   director      8797 non-null   object
#  4   cast          8797 non-null   object
#  5   country       8797 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8797 non-null   int64
#  8   rating        8797 non-null   object
#  9   duration      8797 non-null   object
#  10  listed_in     8797 non-null   object
#  11  description   8797 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 893.4+ KB

# %%
#duration has min and seasons ..so we seperat them using string extract function (regex)
df[['duration_int','duration_type']]=df['duration'].str.extract(r'(\d+)\s*(\w+)')
#\d+ 1 or more digit extract (ex:90 from min,1,2 from seasons)
#s* 0 or more spaces
#\w+ 1or more word characters(letter/number/underscores) (ex:min,season,seasons)
#() groups the matches, (get two columns for 1:number 2:text)
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_5004\3382723021.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['duration_int','duration_type']]=df['duration'].str.extract(r'(\d+)\s*(\w+)')
# C:\Users\shabi\AppData\Local\Temp\ipykernel_5004\3382723021.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['duration_int','duration_type']]=df['duration'].str.extract(r'(\d+)\s*(\w+)')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Not Available
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Not Available
# 4         s5  TV Show           Kota Factory    Not Available
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb    Not Available
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                         Not Available  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8797 entries, 0 to 8806
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        8797 non-null   object
#  1   type           8797 non-null   object
#  2   title          8797 non-null   object
#  3   director       8797 non-null   object
#  4   cast           8797 non-null   object
#  5   country        8797 non-null   object
#  6   date_added     8797 non-null   object
#  7   release_year   8797 non-null   int64
#  8   rating         8797 non-null   object
#  9   duration       8797 non-null   object
#  10  listed_in      8797 non-null   object
#  11  description    8797 non-null   object
#  12  duration_int   8794 non-null   object
#  13  duration_type  8794 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added       0
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# duration_int     3
# duration_type    3
# dtype: int64

# %%
df[df['duration_int'].isna()] #check na cause
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description  \
# 5541  Unknown    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794  Unknown    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813  Unknown    Movies  The comic puts his trademark hilarious/thought...
#
#      duration_int duration_type
# 5541          NaN           NaN
# ...

# %%
df=df[df['duration_int'].notna()] 
#df['duration_int'].notna() returns boolean series:True for rows where duration_int not null,False where it is null
#first df[..] filters the dataframe where only rows where condition is true and keep em

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added       0
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# duration_int     0
# duration_type    0
# dtype: int64

# %%
df.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration         object
# listed_in        object
# description      object
# duration_int     object
# duration_type    object
# dtype: object

# %%
df['duration_int']=df['duration_int'].astype(int)
# Out:
# C:\Users\shabi\AppData\Local\Temp\ipykernel_5004\3883394342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration_int']=df['duration_int'].astype(int)

# %%
df.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration         object
# listed_in        object
# description      object
# duration_int      int64
# duration_type    object
# dtype: object

# %%
df['date_added']=pd.to_datetime(df['date_added'])

# %%
#first we need to remove space from date_added in order to convert it into datetime format
df['date_added']=df['date_added'].str.strip()
#strip removes leading and trailing spaces
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 2
#       1 #first we need to remove space from date_added in order to convert it into datetime format
# ----> 2 df['date_added']=df['date_added'].str.strip()
#       3 #strip removes leading and trailing spaces
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Not Available
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Not Available
# 4         s5  TV Show           Kota Factory    Not Available
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb    Not Available
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                         Not Available  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['date_added']=pd.to_datetime(df['date_added'],errors='coerce')
#errores='coerce' will make invalid dates beome NaT(not a time)

# %%
df.dtypes
# Out:
# show_id                  object
# type                     object
# title                    object
# director                 object
# cast                     object
# country                  object
# date_added       datetime64[ns]
# release_year              int64
# rating                   object
# duration                 object
# listed_in                object
# description              object
# duration_int              int64
# duration_type            object
# platform_era             object
# dtype: object

# %%
df=df[df['date_added'].notna()].copy()
#will createa a completely seperate and independant copy of the filtered data

# %%
df.dtypes
# Out:
# show_id                  object
# type                     object
# title                    object
# director                 object
# cast                     object
# country                  object
# date_added       datetime64[ns]
# release_year              int64
# rating                   object
# duration                 object
# listed_in                object
# description              object
# duration_int              int64
# duration_type            object
# platform_era             object
# dtype: object

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Not Available
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Not Available
# 4         s5  TV Show           Kota Factory    Not Available
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb    Not Available
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                         Not Available  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#i accidentally created a new column datetime instead of changing date_added datatype so dropping it
df.drop(columns=['date_time'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 2
#       1 #i accidentally created a new column datetime instead of changing date_added datatype so dropping it
# ----> 2 df.drop(columns=['date_time'],inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water    Not Available
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Not Available
# 4         s5  TV Show           Kota Factory    Not Available
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb    Not Available
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                         Not Available  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.dtypes
# Out:
# show_id                  object
# type                     object
# title                    object
# director                 object
# cast                     object
# country                  object
# date_added       datetime64[ns]
# release_year              int64
# rating                   object
# duration                 object
# listed_in                object
# description              object
# duration_int              int64
# duration_type            object
# dtype: object

# %% [markdown]
# ### Visualization

# %%
#Type Distribuion(Movies vs Shows)
type_counts=df['type'].value_counts()
plt.figure(figsize=(6,4))
plt.bar(type_counts.index, type_counts.values,color=['orange','skyblue'])
plt.title("Count of Movies vs TV Shows")
plt.xlabel('Type')
plt.ylabel('Count')
plt.grid(axis='y',linestyle='--',alpha=0.6) 
#.grid used to add grid lines. #axis-y:add gridlines only to yaxis(horizontal)
#linestyle --:make the lines dashed
plt.show()

# %%
#Average Movie Duration
movies=df[df['type']=='Movie'] #filters only movies for visualization
movies=movies.dropna(subset=['duration_int']) # drop rows with missing values..although i cleaned the data,just in case
avg_dur=movies['duration_int'].mean()
print("Average Movie Duration:",avg_dur)
# Out:
# Average Movie Duration: 99.57718668407311

# %%
import seaborn as sns

# %%
plt.figure(figsize=(7,4))
sns.histplot(movies['duration_int'],bins=20,color='blue',edgecolor='brown')
plt.axvline(avg_dur,color='red',linestyle='--',label=f'Avg:{avg_dur:.1f} min') # Draw average line vertical on x axis
plt.title("Distribution of Movie Durations")
plt.xlabel("Duration (minutes)")
plt.ylabel("Number of Movies")
plt.legend()
plt.tight_layout() # automatically adjust spacing
plt.show()

# %%
tv=df[df['type']=='TV Show'].copy()
tv['season_count']=tv['duration'].str.extract(r'(\d+)').astype(float) #extract season numbers from the duration column              
#\d  -any digit
#+ -one or more
#() - extract and capture in a group
#use copy() when creaing a slice
avg_seasons=tv['season_count'].mean()

# %%
plt.figure(figsize=(8,5))
sns.histplot(tv['season_count'],bins=15,color='mediumpurple')
plt.axvline(avg_seasons,color='red',linestyle='--',label=f'Avg:{avg_seasons:.1f} seasons')
plt.title('Distribution of TV Show Seasons')
plt.xlabel('Number of Seasons')
plt.ylabel('Number of Shows')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Barplot – Average Movie Duration by Country (Top 5)

country_avg= movies.groupby('country')['duration_int'].mean().sort_values(ascending=False).head(5)
plt.figure(figsize=(10,5))
sns.barplot(y=country_avg.index,x=country_avg.values,color='green',alpha=0.5)
sns.set_theme(style='dark')
plt.title("Average Movie Duration by Top 5 Countries")
plt.ylabel("Countries")
plt.xlabel("Avg Duration")
plt.xticks(rotation=45) # to fix countries name overlapping
plt.show()

# %%
#Boxplot – Distribution of Movie Durations by Rating
plt.figure(figsize=(10,6))
sns.boxplot(data=movies,x='rating',y='duration_int',color='blue')
sns.set_theme(style='white')
plt.title("Distribution of Movie Durations by Rating")
plt.xlabel("Rating")
plt.ylabel("Duration")
plt.xticks(rotation=45)
plt.show()

# %%
#Pie Chart – Count of Movies by Rating(matplot)
rating_counts=movies['rating'].value_counts().head(5)
plt.figure(figsize=(8, 4))
plt.pie(rating_counts,labels=rating_counts.index,autopct='%1.1f%%',startangle=140)
plt.title("Top 5 Movie Rating Distribution")
plt.axis('equal')
plt.legend(
    loc='upper left', 
    bbox_to_anchor=(1, 1)  # moves legend outside
        )
plt.tight_layout()
plt.show()

# %%
#df.to_csv('cleaned_netflix_data.csv',index=False)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'duration_int', 'duration_type'],
#       dtype='object')

# %%
# Create a new column grouping by era
df['platform_era'] = df['release_year'].apply(
    lambda x: 'Classic' if x < 1990 else 'Old School' if x < 2010 else 'Modern'
)

# Plot
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='platform_era', hue='type', palette='Set1')
plt.title('Content Count by Era and Type')
plt.xlabel('Era')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# !pip freeze > requirements.txt
